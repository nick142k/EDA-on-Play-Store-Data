# %% [markdown]
# # 🚀Play Store Data Analysis 📱📊

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Nikhil Sharma

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Objective: This project aimed to perform an in-depth exploratory data analysis (EDA) of Play Store data to extract meaningful insights into app trends and user preferences.
#
# Data Cleaning and Preprocessing: The dataset underwent thorough cleaning and preprocessing procedures to address missing values, standardize data formats, and ensure data integrity.
#
# Exploratory Data Analysis (EDA):
#
# App Ratings Distribution: The distribution of app ratings was analyzed to gauge overall user satisfaction levels.
# App Size vs. Rating: A correlation analysis was conducted to explore the relationship between app size and user ratings.
# App Category Popularity: The popularity of different app categories was examined to identify the most and least popular categories among users.
# Price vs. Downloads/Ratings: The impact of app pricing on download counts and ratings was investigated to understand user behavior towards paid apps.
# Visualization: Various visualization techniques, including histograms, bar charts, and scatter plots, were employed to visually represent the relationships between different variables and derive actionable insights.
#
# Key Findings:
#
# The majority of apps in the dataset received ratings above 4, indicating a high level of user satisfaction.
# A weak positive correlation was observed between app size and ratings, suggesting that larger apps tend to receive slightly higher ratings.
# The most popular app categories were identified as [insert categories], while the least popular categories included [insert categories].
# Free apps exhibited higher download counts and ratings compared to their paid counterparts.
#
# Conclusion:
#
# The EDA yielded valuable insights into the Play Store data, providing a nuanced understanding of user preferences and app performance metrics. These insights can inform strategic decision-making processes related to app development, marketing strategies, and user engagement efforts

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/nick142k/EDA-on-Play-Store-Data

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Explore Play Store app data alongside customer reviews to uncover key factors driving app engagement and success, empowering developers to capture the Android market with actionable insights.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# To identify and leverage crucial insights from Play Store app data and customer reviews, enabling app developers to enhance engagement, optimize user experiences, and maximize success in the competitive Android market

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
data = pd.read_csv('apps.csv')
review_data = pd.read_csv('user_reviews.csv')

# %%
review_data.dropna(inplace=True)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
data.head()
# Out:
#    Unnamed: 0                                                App  \
# 0           0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1           1                                Coloring book moana
# 2           2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3           3                              Sketch - Draw & Paint
# 4           4              Pixel Draw - Number Art Coloring Book
#
#          Category  Rating  Reviews  Size     Installs  Type Price  \
# 0  ART_AND_DESIGN     4.1      159  19.0      10,000+  Free     0
# 1  ART_AND_DESIGN     3.9      967  14.0     500,000+  Free     0
# 2  ART_AND_DESIGN     4.7    87510   8.7   5,000,000+  Free     0
# 3  ART_AND_DESIGN     4.5   215644  25.0  50,000,000+  Free     0
# 4  ART_AND_DESIGN     4.3      967   2.8     100,000+  Free     0
#
#   Content Rating                     Genres      Last Updated  \
# 0       Everyone               Art & Design   January 7, 2018
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Shape of dataset
data.shape
# Out:
# (9659, 14)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9659 entries, 0 to 9658
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      9659 non-null   int64
#  1   App             9659 non-null   object
#  2   Category        9659 non-null   object
#  3   Rating          8196 non-null   float64
#  4   Reviews         9659 non-null   int64
#  5   Size            8432 non-null   float64
#  6   Installs        9659 non-null   object
#  7   Type            9659 non-null   object
#  8   Price           9659 non-null   object
#  9   Content Rating  9659 non-null   object
#  10  Genres          9659 non-null   object
#  11  Last Updated    9659 non-null   object
#  12  Current Ver     9651 non-null   object
#  13  Android Ver     9657 non-null   object
# dtypes: float64(2), int64(2), object(10)
# memory usage: 1.0+ MB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count

print(f'Missing Values'+'\n'+'-'*15)

null_visualization = data.isnull().sum()
null_visualization
# Out:
# Missing Values
# ---------------
# Unnamed: 0           0
# App                  0
# Category             0
# Rating            1463
# Reviews              0
# Size              1227
# Installs             0
# Type                 0
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          2
# dtype: int64

# %%
# Visulaizing null values using null values to watch where are those Garbage.
plt.figure(figsize=(8, 6))
sns.heatmap(data.isnull(), cmap='viridis', cbar=False)
plt.title('Heatmap of Missing Values')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# 1. Columns and Rows: The dataset comprises 14 columns and 9659 rows.
# 3. Null Values: There are missing values present in several columns of the dataset, such as 'Rating', 'Size', 'Current Ver', and 'Android Ver'.
# 3. Duplicates: There are no duplicates present in this dataset.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
print(
    f'Columns of our dataset'+'\n'+'-'*22
)
data.columns
# Out:
# Columns of our dataset
# ----------------------
# Index(['Unnamed: 0', 'App', 'Category', 'Rating', 'Reviews', 'Size',
#        'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated',
#        'Current Ver', 'Android Ver'],
#       dtype='object')

# %%
# Dataset Describe
data.describe()
# Out:
#          Unnamed: 0       Rating       Reviews         Size
# count   9659.000000  8196.000000  9.659000e+03  8432.000000
# mean    5666.172896     4.173243  2.165926e+05    20.395327
# std     3102.362863     0.536625  1.831320e+06    21.827509
# min        0.000000     1.000000  0.000000e+00     0.000000
# 25%     3111.500000     4.000000  2.500000e+01     4.600000
# 50%     5814.000000     4.300000  9.670000e+02    12.000000
# 75%     8327.500000     4.500000  2.940100e+04    28.000000
# max    10840.000000     5.000000  7.815831e+07   100.000000

# %%
data.describe().corr()
# Out:
#             Unnamed: 0    Rating   Reviews      Size
# Unnamed: 0    1.000000  0.422368  0.546675  0.429779
# Rating        0.422368  1.000000 -0.146834  0.999947
# Reviews       0.546675 -0.146834  1.000000 -0.137062
# Size          0.429779  0.999947 -0.137062  1.000000

# %% [markdown]
# ### Variables Description

# %% [markdown]
# 1. Data: represents Dataframe
# 2. replaceing_nan_with_mean_in_rating: Replacing the Nan values in the Rating column with mean of of rating.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
print(f"Unique value count of all columns"+'\n'+'-'*33)
data.nunique()
# Out:
# Unique value count of all columns
# ---------------------------------
# Unnamed: 0        9659
# App               9659
# Category            33
# Rating              39
# Reviews           5330
# Size               191
# Installs            21
# Type                 2
# Price               92
# Content Rating       6
# Genres             118
# Last Updated      1377
# Current Ver       2769
# Android Ver         33
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %%
data.head()
# Out:
#    Unnamed: 0                                                App  \
# 0           0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1           1                                Coloring book moana
# 2           2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3           3                              Sketch - Draw & Paint
# 4           4              Pixel Draw - Number Art Coloring Book
#
#          Category  Rating  Reviews  Size     Installs  Type Price  \
# 0  ART_AND_DESIGN     4.1      159  19.0      10,000+  Free     0
# 1  ART_AND_DESIGN     3.9      967  14.0     500,000+  Free     0
# 2  ART_AND_DESIGN     4.7    87510   8.7   5,000,000+  Free     0
# 3  ART_AND_DESIGN     4.5   215644  25.0  50,000,000+  Free     0
# 4  ART_AND_DESIGN     4.3      967   2.8     100,000+  Free     0
#
#   Content Rating                     Genres      Last Updated  \
# 0       Everyone               Art & Design   January 7, 2018
# ...

# %%
# In this  cell I will define a funtion called remove_emojis, for my first column which is App using regular expression.

import re

# Define the regular expression pattern and using Regular expression unicode's for filter App column.

pattern = r"[" \
          u"\U0001F600-\U0001F64F" \
          u"\U0001F300-\U0001F5FF" \
          u"\U0001F680-\U0001F6FF" \
          u"\U0001F1E0-\U0001F1FF" \
          "]"

# Function to remove emojis and flags
def remove_emojis(text):
    return re.sub(pattern, '', text)

# Apply the function to the 'App' column
data['App'] = data['App'].apply(lambda x: remove_emojis(x))

# %%
# In this cell  I have cleaned three columns which has inconsitent data present in the data, again using regular expression. 
# But before that let's first remvove  the 'Unnamed: 0' column which has no use for in the dataframe using Python drop inbuilt funtion.

data.drop(columns= 'Unnamed: 0',inplace = True) 



data['Price'] = data['Price'].replace(r'[$]','',regex=True).astype(float)
data['Installs']=data['Installs'].replace(r'[+,]','',regex=True)
data['Installs']=data['Installs'].astype(int)

# %% [markdown]
# ### From now I am going to handle null values available in the columns

# %% [markdown]
# ### Let's first explore the rating columns which have total 1463 rows with NaN values.

# %%
#Exploring the Rating column to analyze the ouliers
sns.boxplot(data = data['Rating'])
plt.title('Box plot of rating column')
# Out:
# Text(0.5, 1.0, 'Box plot of rating column')

# %%
# Exploring the Rating column for itentify the column follows the Normal distribution or not 

sns.kdeplot(data=data[['Rating']])
plt.title('Kernal density plot for analysing  Normal Distribution')
# Out:
# Text(0.5, 1.0, 'Kernal density plot for analysing  Normal Distribution')

# %%
# From my above analysis, I have seen that the Rating column is has very much outliers and it was also not following normal distribution so in the below code i have imputer the null values with median of the column.

replaceing_nan_with_mean_in_rating = data.groupby('Category')['Rating'].transform('median')
data['Rating'].fillna(replaceing_nan_with_mean_in_rating,inplace=True)
data['Rating']
# Out:
# 0       4.1
# 1       3.9
# 2       4.7
# 3       4.5
# 4       4.3
#        ...
# 9654    4.5
# 9655    5.0
# 9656    4.3
# 9657    4.5
# 9658    4.5
# Name: Rating, Length: 9659, dtype: float64

# %% [markdown]
# ### Manipulating the 'Size' column has also has total  1227 NuN value.

# %%
# Exploring the size column for itentify the outliers

sns.boxplot(data=data['Size'])
plt.title('Box plot of size column')
# Out:
# Text(0.5, 1.0, 'Box plot of size column')

# %%
# Exploring the size column for itentify the column follows the Normal distribution or not 

sns.kdeplot(data=data['Size'])
plt.title('Kernal density plot for checking Normal distibution')
# Out:
# Text(0.5, 1.0, 'Kernal density plot for checking Normal distibution')

# %%
replacing_mean_with_median_in_size=data.groupby('Category')['Size'].transform('median')# From my above analysis, I have seen that the size column is has very much outliers and it was also not following normal distribution so in the below code i have imputer the null values with median of the column.

data['Size'].fillna(replacing_mean_with_median_in_size,inplace=True)

# %%
data= data.dropna()

# %%
data.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# I began by removing the 'Unnamed: 0' column and then proceeded with various data transformations. I created a 'remove_emojis' function leveraging regex to cleanse emojis from the 'App' column. Additionally, I removed arithmetic symbols and commas from the 'Content rating' column to facilitate integer formatting, followed by eliminating currency symbols from the 'Price' column using regex for consistent integer conversion. The 'Installs' column underwent a similar process to ensure data uniformity and conversion to integer type.
#
# Subsequently, I applied an imputer to replace missing values with the median in the 'Size' and 'Rating' columns. Finally, I utilized the 'dropna' method to remove all null values from the dataset, resulting in a refined dataset ready for analysis or model training

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %%
data.head() #exploring dataframe
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size  Installs  Type  Price Content Rating  \
# 0      159  19.0     10000  Free    0.0       Everyone
# 1      967  14.0    500000  Free    0.0       Everyone
# 2    87510   8.7   5000000  Free    0.0       Everyone
# 3   215644  25.0  50000000  Free    0.0           Teen
# 4      967   2.8    100000  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
data.shape  # Checking the shape of the datafrme
# Out:
# (9649, 13)

# %%
catag_var = data[['Category','Rating','Size','Installs','Type','Price','Content Rating','Genres','Android Ver']]

# %% [markdown]
# # Let's begin our Data visualization

# %% [markdown]
# # Chart - 1

# %%
import matplotlib.pyplot as plt    #Matplot and seaborn are python libarary help us make cool visualization 
import seaborn as sns
sns.countplot(x = 'Category',data=data, order=data['Category'].value_counts().index)
plt.xticks(rotation=90)
plt.title('Category count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
# --> Displaying the frequency distribution of categorical apps from the dataset using Seaborn and Matplotlib for visualization.
#
# --> The countplot showcases the occurrence of each category, ordered by frequency to emphasize the most prevalent categories.
#
# -->Adjusting x-label rotation enhances readability for better interpretation of the plot.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here:
# "In the Play Store dataset, the most prevalent category of applications corresponds to 'Family' types, indicating a higher availability. Conversely, 'Beauty' applications exhibit the lowest count among the categorized apps in the dataset."

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here:
# So, based on the chart, it seems that the last five applications have lower counts compared to others. If I'm considering launching an application from these options, it's crucial to analyze these five to determine which one has the highest demand among them. This analysis will help in making an informed decision about which specific application might have more potential despite the lower count among these categories.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 pie chart of free and paid comparision
data['Type'].value_counts().plot(kind='pie',autopct='%1.1f%%')
plt.title('Free and paid application')
# Out:
# Text(0.5, 1.0, 'Free and paid application')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Comparing the two variable using pie chart is great idea, so i have used this chart to compare the free and paid application in the playstore dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# In the dataset there are 92.2% free and only 7.8% paid  application are in the Playstore dataset.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
#
# ### Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# As i can see there is very low compititores which are only 7.8% paid application is present in the play store. So, there is a very high chance to of growth of in paid application.

# %% [markdown]
# #### Chart - 3

# %%
from wordcloud import WordCloud

# Concatenate all genres into a single string
text = ' '.join(data['Genres'])

# Generate word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# Display the word cloud using matplotlib
plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Remove axis
plt.title('Word Cloud of Genres')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here. I have choosen this char to analyse most frequent  of app genres.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here:  From the above visualization, I can say i medical,tools,entertainment,fitness,education,mgazines,etc are more highlated key words or we can say app genres in the dataset.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here:
# Positive Impact:
# Identifying popular genres (like "fitness" or "education") helps businesses cater to current trends, potentially increasing user engagement and revenue by aligning products or services with market interests.
#
# Negative Impact:
# Overemphasizing prevalent genres (e.g., "map navigation","arcad","weather" or "trivia") may lead to intense competition or limit audience reach. Neglecting less highlighted genres could mean missing out on potential market segments and growth opportunities.

# %% [markdown]
# #### Chart - 4

# %%
downlodes  = data.groupby('Category')['Installs'].sum().sort_values(ascending=True)
plt.figure(figsize=(12,4))
plt.bar(x = downlodes.index, height = downlodes.values)
plt.xticks(rotation= 90)
plt.title('Total Downlodes Of App category ')
plt.xlabel('CATEGORY')
plt.ylabel('DOWNLODES')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I have taken this chart type because i want to see which categorical applications are more in downlodes.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. I can see ther is no compitiion of 'Game' applications and they  are on the peak.
# 2. There are four to five clustur i am able to see;[vidio_player,social,entertainment],
# [phoggraphy,productivity,game],[tools,new and magazines,books and reference,shopping],etc.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
#  Answer Here  :- Yah, i can say "Game" appplication have more in downlodes and also there are not much application available (as per first chat). So i will say if we can lauch more competitive communication application so ther much be a chance of potentential growth ( as per the law of demand and supply).

# %% [markdown]
# #### Chart - 5

# %%
plt.figure(figsize=(13,8))
print(f"Average Rating {data['Rating'].mean()}")

data["Rating"].hist()
plt.title(" Google Play Apps Rating Distribution")
plt.ylabel("App Count")
plt.xlabel("Rating out of 5.0")
plt.show()
# Out:
# Average Rating 4.189532594051197

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here. I have plot the histograme to anlyse which is most rated range in playstore.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here.
# Most of the  app category are rated 4.5 and very less nuber of application are in the range of 1.0 to 3.0.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here.
# The insights gained from the analysis of app ratings can indeed help create a positive business impact. Understanding that most app categories are rated around 4.5 indicates that users generally have a positive perception of the apps available in the Play Store. This knowledge can be leveraged by developers and businesses to focus on maintaining and improving the quality of their apps, as positive ratings are often correlated with higher user engagement, retention, and ultimately, revenue.
#
# However, the presence of very few applications in the lower rating range of 1.0 to 3.0 may indicate areas where negative growth could occur if not addressed. Apps in this range are likely to have significant issues that lead to poor user experiences, such as bugs, crashes, or lack of useful features. If developers and businesses do not actively work to address these issues and improve the quality of these apps, they may see negative growth in terms of user downloads, ratings, and ultimately, revenue. Therefore, it is crucial for developers to prioritize addressing the issues highlighted by lower-rated apps to avoid negative growth and maintain a positive business impact.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
rating_comparision = data.groupby('Category')['Rating'].mean().sort_values(ascending=True)
plt.figure(figsize=(9,6))
sns.barplot(x=rating_comparision.values,y=rating_comparision.index,order = rating_comparision.index,)
plt.title('Freqency of unique data by Rating')
plt.xlabel('Rating')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Compairing all tyes of application with there rating using a bar chart is a good visualization.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# As you can see evnets, books and art_design application are highly rated in Play store.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# As you can see the chat, the no one in the market who have scored 5 star rated category applicatio, but above 4 is also a quite good number accourding to rating. So there is huge compitition in the play store market. So if someone is  someone is planning to lauch a application i playstore, laucher have much have worry about the product. Because if it the application will not score good rating in the store then, there is high chances that is going to fail in the market.

# %% [markdown]
# #### Chart - 9

# %%
sentiment_df = pd.merge(review_data, data[["App","Type"]] , how='inner', on="App")

# %%
sentiment_df.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You         Works great especially going grocery store
# 3  10 Best Foods for You                                       Best idea us
# 4  10 Best Foods for You                                           Best way
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity  Type
# 0  Positive                1.00                0.533333  Free
# 1  Positive                0.25                0.288462  Free
# 2  Positive                0.40                0.875000  Free
# 3  Positive                1.00                0.300000  Free
# 4  Positive                1.00                0.300000  Free

# %%
free_apps = sentiment_df.groupby('Sentiment')['Sentiment'].count()
plt.figure(figsize=(4, 4))  
colors = ['crimson', 'orange', 'gold']  # colors for each section
plt.pie(free_apps, labels=free_apps.index, colors=colors, autopct='%1.1f%%', startangle=140)
plt.title('Sentiment Distribution')  
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# I have selected Pie chart to compare sentiments of customer review.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Ovalall  percentange  of reviewed  positive sentiments is 64.2 % , negative sentiment is 22.3 % and neutral sentiments is 13.5 %.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the gained insights can help create a positive business impact. By understanding the distribution of sentiments in the reviews, businesses can tailor their products or services to better meet customer needs and preferences. Positive sentiments indicate areas where the business is performing well, which can be leveraged for marketing and customer retention strategies. Negative sentiments highlight areas for improvement, allowing businesses to address customer concerns and enhance their offerings.
#
# However, if there are insights that indicate negative growth, such as a significant increase in negative sentiments over time, this could be a cause for concern. Negative growth in sentiments could indicate issues with product quality, customer service, or other aspects of the business that need to be addressed promptly to prevent further decline in customer satisfaction and potential loss of business

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 v# Filter the DataFrame for 'Free' and 'Paid' types
free_apps = sentiment_df[sentiment_df['Type'] == 'Free']
paid_apps = sentiment_df[sentiment_df['Type'] == 'Paid']

# Create count plots for sentiments in 'Free' and 'Paid' apps
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
sns.countplot(x='Sentiment', data=free_apps, order=['Positive', 'Negative', 'Neutral'])
plt.title('Sentiments in Free Apps')

plt.subplot(1, 2, 2)
sns.countplot(x='Sentiment', data=paid_apps, order=['Positive', 'Negative', 'Neutral'])
plt.title('Sentiments in Paid Apps')

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# To the compare the sentiments of free and paid application.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?
# Both paid and free application have almost similar performance  on behalf of bar chart.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The business impact of both paid and free applications having similar sentiments could be that users perceive value in both types of apps, potentially leading to increased trust and willingness to pay for premium features in free apps.

# %% [markdown]
# #### Chart - 11

# %%
plt.figure(figsize=(8, 5))

sns.kdeplot(data=free_apps['Sentiment_Polarity'], label='Free Apps', shade=True)
sns.kdeplot(data=paid_apps['Sentiment_Polarity'], label='Paid Apps', shade=True)

plt.title('Distribution of Sentiment Polarity')
plt.xlabel('Sentiment Polarity')
plt.ylabel('Density')

plt.legend()
plt.show()
# Out:
# C:\Users\nikhi\AppData\Local\Temp\ipykernel_5996\736548406.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=free_apps['Sentiment_Polarity'], label='Free Apps', shade=True)
# C:\Users\nikhi\AppData\Local\Temp\ipykernel_5996\736548406.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=paid_apps['Sentiment_Polarity'], label='Paid Apps', shade=True)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# KDE (Kernel Density Estimate) plot for visualizing the distribution of sentiment polarity values is one of many options available

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
# Sentiments in Free Apps:
# Neutral Polarity Dominance: A larger area around 0.00 indicates a prevalent occurrence of neutral sentiments among free apps, suggesting a balanced distribution around the neutral sentiment.
#
# Extreme Positive Polarity: The considerable area between 0.5 and 1.00 signifies a notable occurrence of exceptionally positive sentiments among free apps, showcasing a higher proportion of very positive opinions.
#
# Sentiments in Paid Apps:
# Majority in Positive Range (0 to 0.5): Most sentiments fall between 0 and 0.5, indicating a prevalent but less extreme positive sentiment distribution in paid apps compared to free apps.
#
# Absence of Extreme Negative Sentiments: The absence of sentiments below -0.5 suggests a lack of highly negative opinions among paid apps, demonstrating a minimum cap for negative sentiments, likely indicating greater overall satisfaction with paid apps

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
# Positive Business Impact:
# Targeted Marketing Strategies: Understanding the sentiment distributions can help tailor marketing strategies. For instance, emphasizing extreme positive sentiments for free apps could attract more users, while highlighting overall satisfaction in paid apps might retain existing customers.
#
# Product Development: Insights into sentiment distribution can guide product improvements. Focusing on enhancing positive sentiment aspects in both free and paid apps can lead to higher user satisfaction and retention.
#
# User Experience Enhancement: Addressing the prevalence of neutral sentiments in free apps can help improve user experience. Identifying and rectifying issues causing neutrality might lead to increased engagement.
#
# Insights Leading to Negative Growth:
# Extreme Negative Sentiments in Free Apps: If users express highly negative sentiments in free apps, it could lead to decreased usage, uninstallations, or poor app ratings, impacting future downloads and growth negatively.
#
# Lack of Extreme Negative Sentiments in Paid Apps: While a lack of extremely negative sentiments is positive, it might mask potential issues or dissatisfaction that users hesitate to express. Ignoring subtler negative sentiments in paid apps could lead to complacency, hindering improvements and causing negative growth in the long run.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
plt.figure(figsize=(8, 6))
sns.boxplot(data=data, x='Category', y='Rating', palette='viridis').axhline(data['Rating'].mean())
plt.title('Distribution of Reviews by Category')
plt.xlabel('Category')
plt.ylabel('Reviews')
plt.xticks(rotation = 90)
plt.show()
# Out:
# C:\Users\nikhi\AppData\Local\Temp\ipykernel_5996\3574065616.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x='Category', y='Rating', palette='viridis').axhline(data['Rating'].mean())

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here. I have taken this chart to observe the  performance by their category.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
# 1. Performance of all app categories is mostly Decent. Highest quality apps with 50% apps with a rating higher than 4.5 are Health and Fitness and Book and Reference app. This is considered to be extremely high!
#
# 2. However, the apps in Dating category having lower rating than the average ratings is 50%

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
# Positive Business Impact:
# Targeted Investment: Identifying Health and Fitness, Book and Reference categories as high-performing can guide investment decisions. Allocating resources and efforts towards these successful categories could yield higher returns and user satisfaction.
#
# Improving Quality Standards: Recognizing lower-rated categories like Dating, Lifestyle, Family, and Finance enables focused improvements. Enhancing app quality, user experience, and addressing issues within these categories can lead to positive growth.
#
# Market Differentiation: Highlighting exceptional categories allows businesses to emphasize strengths in marketing efforts, standing out in the market and potentially attracting more users and revenue.
#
# Insights Leading to Negative Growth:
# Lower Quality Categories: Categories marked by junk apps or a significant percentage of apps below average ratings could lead to negative growth. Users might lose trust or interest in these categories, impacting overall user engagement and satisfaction.
#
# Negative User Sentiment: Lower-rated categories might result in negative user sentiments, leading to decreased app downloads, poor reviews, and diminished market competitiveness.

# %% [markdown]
# #### Chart - 13 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
statiscal_info = data.describe()
corr_matrix = statiscal_info.corr()
sns.heatmap(corr_matrix,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# I used  this chart  to  analysis of the relationship between the variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# Based on the visualizations, there appears to be a consistent and comparable relationship between the variables analyzed, indicating a stable pattern or trend across different aspects of the data

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights gained from the visualizations can indeed help create a positive business impact. Understanding the consistent and comparable relationship between the variables analyzed provides valuable information for businesses to make informed decisions. For example, if certain features or characteristics of apps are consistently associated with higher ratings or more downloads, businesses can prioritize these aspects in their app development or marketing strategies to attract more users and improve user satisfaction.
#
# However, if there are insights that indicate negative growth, such as a consistent negative relationship between certain variables and user ratings or downloads, this could be a cause for concern. For instance, if certain app categories consistently receive lower ratings or have fewer downloads compared to others, this may indicate that these categories are less popular or have more competition. In such cases, businesses may need to reevaluate their strategies for these categories to improve their performance and avoid negative growth.
#
# Overall, the insights gained from the visualizations can help businesses identify trends and patterns in user behavior, allowing them to make strategic decisions to enhance their products or services and ultimately create a positive business impact.

# %% [markdown]
# #### Chart - 14 - Pair Plot

# %%
# Pair Plot visualization code

sns.pairplot(data=data,diag_kind='kde')
# Out:
# c:\Users\nikhi\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# I have picked the pairt plot to analyse the all the numerical  variable  for checking normality.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
# I can see the data is not normalized , also there is no proper formation of group found.

# %% [markdown]
# ### 3.  Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights gained from the analysis of the unnormalized data and the lack of proper formation of groups in the pair plot may not directly lead to a positive business impact. These issues indicate that the data may be challenging to analyze and interpret, potentially limiting the effectiveness of any conclusions drawn from the analysis.
#
# However, addressing these issues can lead to positive outcomes. Normalizing the data can improve the performance of analytical models and help in making more accurate predictions or decisions based on the data. Properly forming groups in the pair plot can also reveal hidden patterns or relationships in the data, which can be valuable for understanding customer behavior or market trends.
#
# Therefore, while the current state of the data may not directly lead to negative growth, addressing these issues can help unlock valuable insights that can positively impact business outcomes.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.
#
#
# Based on the exploratory data analysis (EDA) findings, app developers can enhance user engagement by incorporating category-specific features and design elements. For instance, in the "Education" category, interactive quizzes and progress tracking can improve user retention. In the "Health & Fitness" category, integrating workout plans and calorie trackers can enhance user experience. "Entertainment" apps can benefit from personalized content recommendations and social sharing features. In "Productivity" apps, including task management tools and collaboration features can boost user engagement. By tailoring features and design elements to match category preferences, developers can optimize user engagement and improve app performance in the Play Store.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# App Development Strategy: Focus on developing apps that cater to popular categories identified in the analysis, such games,communication and tools etc.. to maximize user engagement and downloads.
#
# User Engagement: Given the positive correlation between app size and ratings, consider enhancing app features and content to provide a more comprehensive user experience, which may lead to higher ratings and user satisfaction.
#
# Pricing Strategy: Since free apps tend to attract more downloads and higher ratings, consider offering a freemium model where basic features are free with the option to purchase premium features, allowing you to monetize while maintaining user engagement.
#
# Marketing and Promotion: Utilize insights on popular categories and user preferences to tailor marketing strategies and promotions, increasing visibility and downloads for your apps.
#
# Competitive Analysis: Continuously monitor competitors' apps in popular categories to identify trends and opportunities for differentiation, helping you stay competitive in the market.
#
# User Feedback Incorporation: Actively solicit and incorporate user feedback to improve app quality and address user preferences, leading to higher ratings and increased user retention.
#
# Localization and Regional Targeting: Consider localizing apps or targeting specific regions based on the popularity of app categories in different geographic locations, optimizing user engagement and downloads.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
